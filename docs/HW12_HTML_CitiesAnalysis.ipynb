# %% [markdown]
# #Load in the data and create the visualizations

# %%
#Dependencies
import pandas as pd
import seaborn as sb

# %%
df = pd.read_csv(r'cities.csv')
df.head()
# Out:
#    City_ID          City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0  jacareacanga           0      BR  1528902000        62  -6.22
# 1        1    kaitangata         100      NZ  1528905304        94 -46.28
# 2        2      goulburn          20      AU  1528905078        91 -34.75
# 3        3          lata          76      IN  1528905305        89  30.78
# 4        4    chokurdakh           0      RU  1528905306        88  70.62
#
#       Lng  Max Temp  Wind Speed
# 0  -57.76     89.60        6.93
# 1  169.85     42.61        5.64
# 2  149.72     44.32       10.11
# 3   78.62     59.89        0.94
# 4  147.90     32.17        2.95

# %%
df.describe()
# Out:
#          City_ID  Cloudiness          Date    Humidity         Lat  \
# count  547.00000  547.000000  5.470000e+02  547.000000  547.000000
# mean   273.00000   42.166362  1.528904e+09   70.349177   21.066051
# std    158.04957   35.620143  1.571072e+03   23.450997   33.360137
# min      0.00000    0.000000  1.528901e+09    5.000000  -54.810000
# 25%    136.50000    1.000000  1.528902e+09   55.500000   -5.615000
# 50%    273.00000   40.000000  1.528905e+09   74.000000   26.190000
# 75%    409.50000   75.000000  1.528905e+09   89.500000   50.035000
# max    546.00000  100.000000  1.528906e+09  100.000000   78.220000
#
#               Lng    Max Temp  Wind Speed
# count  547.000000  547.000000  547.000000
# mean    17.467495   67.870512    8.593583
# std     88.441615   16.750916    5.736229
# min   -179.170000   25.690000    0.720000
# 25%    -61.405000   55.400000    3.740000
# 50%     19.240000   70.420000    7.310000
# 75%     92.485000   79.870000   12.065000
# ...

# %%
df.isnull().sum()
# Out:
# City_ID       0
# City          0
# Cloudiness    0
# Country       2
# Date          0
# Humidity      0
# Lat           0
# Lng           0
# Max Temp      0
# Wind Speed    0
# dtype: int64

# %%
df.Date = pd.to_datetime(df.Date)
df.Date.describe()
# Out:
# count                               547
# unique                              213
# top          1970-01-01 00:00:01.528902
# freq                                124
# first     1970-01-01 00:00:01.528900860
# last      1970-01-01 00:00:01.528905646
# Name: Date, dtype: object

# %%
x ,y = pd.Series(df['Lat'], name = "Latitude"), pd.Series(df['Max Temp'], name = 'Max Temp (F)')

ax = sb.regplot(x = x, y =y, marker = "+")
ax.set_title('Max Temp as a function of Latitude')
fig1 = ax1.get_figure()
fig1.savefig('Lat vs Max Temp.png')

# %%
x ,y = pd.Series(df['Lat'], name = "Latitude"), pd.Series(df['Humidity'], name = 'Humidity %')

ax1 = sb.regplot(x = x, y =y, marker = "+")
ax1.set_title('Humidity as a function of Latitude')
fig = ax1.get_figure()
fig.savefig('Lat vs Humidity.png')

# %%
x ,y = pd.Series(df['Lat'], name = "Latitude"), pd.Series(df['Cloudiness'], name = 'Cloudiness %')

ax2 = sb.regplot(x = x, y =y, marker = "+")
ax2.set_title('Cloudiness as a function of Latitude')
fig2 = ax1.get_figure()
fig2.savefig('Lat vs Cloudiness.png')

# %%
x ,y = pd.Series(df['Lat'], name = "Latitude"), pd.Series(df['Wind Speed'], name = 'Wind Speed (MPH)')

ax3 = sb.regplot(x = x, y =y, marker = "+")
ax3.set_title('Wind Speed as a function of Latitude')
fig3 = ax1.get_figure()
fig3.savefig('Lat vs Wind Speed.png')
